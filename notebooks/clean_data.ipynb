# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
clean_data = pd.read_csv("../data/processed/clean_data.csv")
print(clean_data.shape)
clean_data.head(10)
# Out:
# (253776, 12)
#         brand     model    vehicleType  power    gearbox  kilometer  fuelType  \
# 0        audi        a4          coupe  190.0     manual   125000.0    diesel
# 1        jeep     grand            suv  163.0  automatic   125000.0    diesel
# 2  volkswagen      golf        compact   75.0     manual   150000.0  gasoline
# 3       skoda     fabia        compact   69.0     manual    90000.0    diesel
# 4         bmw  3-series          sedan  102.0     manual   150000.0  gasoline
# 5     peugeot   2-reihe    convertible  109.0     manual   150000.0  gasoline
# 6        ford     c-max            van  125.0     manual    30000.0  gasoline
# 7  volkswagen      golf        compact  101.0     manual   150000.0  gasoline
# 8       mazda   3-reihe          sedan  105.0     manual   150000.0  gasoline
# 9  volkswagen    passat  station-wagon  140.0     manual   150000.0    diesel
#
#    yearOfRegistration   seller dataSource  price_reference_year  price
# 0                2011  private     kaggle                2016.0  18300
# 1                2004  private     kaggle                2016.0   9800
# 2                2001  private     kaggle                2016.0   1500
# 3                2008  private     kaggle                2016.0   3600
# 4                1995  private     kaggle                2016.0    650
# 5                2004  private     kaggle                2016.0   2200
# 6                2014  private     kaggle                2016.0  14500
# 7                1998  private     kaggle                2016.0    999
# 8                2004  private     kaggle                2016.0   2000
# 9                2005  private     kaggle                2016.0   2799

# %%
clean_data['kilometer'].describe()
# Out:
# count    253776.000000
# mean     122539.872112
# std       40928.517873
# min           0.000000
# 25%      100000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      225000.000000
# Name: kilometer, dtype: float64

# %%
clean_data['power'].describe()
# Out:
# count    253776.000000
# mean        128.319008
# std          53.483727
# min           5.000000
# 25%          90.000000
# 50%         118.000000
# 75%         160.000000
# max         258.500000
# Name: power, dtype: float64

# %%
clean_data['yearOfRegistration'].describe()
# Out:
# count    253776.000000
# mean       2004.294799
# std           7.297045
# min        1910.000000
# 25%        2000.000000
# 50%        2005.000000
# 75%        2009.000000
# max        2023.000000
# Name: yearOfRegistration, dtype: float64

# %%
clean_data['price'].describe()
# Out:
# count    2.537760e+05
# mean     7.170918e+03
# std      1.347700e+04
# min      5.000000e+02
# 25%      1.799000e+03
# 50%      3.999000e+03
# 75%      8.900000e+03
# max      1.250000e+06
# Name: price, dtype: float64

# %%
clean_data['brand'].unique()
# Out:
# <StringArray>
# [         'audi',          'jeep',    'volkswagen',         'skoda',
#            'bmw',       'peugeot',          'ford',         'mazda',
#         'nissan',       'renault', 'mercedes-benz',          'opel',
#        'citroen',         'honda',          'fiat',          'mini',
#          'smart',       'hyundai',          'seat',        'subaru',
#          'volvo',    'mitsubishi',    'alfa-romeo',           'kia',
#         'suzuki',        'lancia',       'porsche',        'toyota',
#      'chevrolet',         'dacia',      'daihatsu',      'chrysler',
#         'jaguar',        'daewoo',         'rover',          'saab',
#     'land-rover',       'trabant',          'lada',         'cupra',
#             'mg',            'ds',           'byd',       'ferrari',
#          'dodge',            'dr',         'tesla',       'bentley',
#    'lamborghini',     'leapmotor',         'omoda',           'evo',
#          'micro',          'togg',           'xev',           'kgm',
#        'lynk-co',         'xpeng',        'abarth',      'polestar',
#   'aston-martin',       'maybach',      'maserati',     'ssangyong',
#         'jaecoo',         'aixam',           'emc',         'lotus',
#          'ineos',        'alpina',   'sportequipe',      'infiniti',
#          'lexus']
# Length: 73, dtype: str

# %%
clean_data['model'].unique()
# Out:
# <StringArray>
# [           'a4',         'grand',          'golf',         'fabia',
#       '3-series',       '2-reihe',         'c-max',       '3-reihe',
#         'passat',        'navara',
#  ...
#            'x7m',          'evo5',          'g500',        'eqe300',
#          'nv200',        'e-golf',     'onecabrio',         'ioniq',
#  'cooperclubman',        'cle200']
# Length: 717, dtype: str

# %%
clean_data['vehicleType'].unique()
# Out:
# <StringArray>
# [        'coupe',           'suv',       'compact',         'sedan',
#    'convertible',           'van', 'station-wagon',         'other']
# Length: 8, dtype: str

# %%
clean_data['fuelType'].unique()
# Out:
# <StringArray>
# ['diesel', 'gasoline', 'lpg', 'other', 'hybrid', 'cng', 'electric']
# Length: 7, dtype: str

# %%
clean_data['gearbox'].unique()
# Out:
# <StringArray>
# ['manual', 'automatic', 'semi-automatic']
# Length: 3, dtype: str

# %%
clean_data['seller'].unique()
# Out:
# <StringArray>
# ['private', 'dealer']
# Length: 2, dtype: str
